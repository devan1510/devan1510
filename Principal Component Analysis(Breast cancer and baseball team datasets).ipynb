# %% [markdown]
# # principal component analysis(breast cancer)

# %%
# imports for the projects
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# imports to upload the dataset
from sklearn.datasets import load_breast_cancer

# %%
# load the dataset and convert into a pandas dataframe
cancer_data= load_breast_cancer()
df= pd.DataFrame(cancer_data.data,columns= cancer_data.feature_names)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
# imports for scaling the data
from sklearn.preprocessing import StandardScaler
stand_scaler= StandardScaler()
scaled_data= stand_scaler.fit_transform(df)

# %%
scaled_df= pd.DataFrame(scaled_data,columns= df.columns)

# %%
# perform principal component analysis on the scaled_dtaa
from sklearn.decomposition import PCA
pca= PCA(n_components= 3)
pca_data= pca.fit_transform(scaled_data)

# %%
scaled_df.shape,pca_data.shape
# Out:
# ((569, 30), (569, 3))

# %%
pca_df= pd.DataFrame(pca_data)

# %%
# visualise the data
fig= plt.figure(figsize= (10,10))
ax= fig.add_subplot(projection= "3d")
ax.scatter(data= pca_df,xs= "pca1",ys= "pca2",zs= "pca3",c=cancer_data.target)

# %% [markdown]
# # baseball team (example 2)

# %%
# imports for the dataset 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset
df= pd.read_csv("C:\\kmeans clustering\\500hits.csv",encoding='latin1')
# Out:
#          PLAYER  YRS     G     AB     R     H   2B   3B   HR   RBI    BB  \
# 0       Ty Cobb   24  3035  11434  2246  4189  724  295  117   726  1249
# 1   Stan Musial   22  3026  10972  1949  3630  725  177  475  1951  1599
# 2  Tris Speaker   22  2789  10195  1882  3514  792  222  117   724  1381
# 3   Derek Jeter   20  2747  11195  1923  3465  544   66  260  1311  1082
# 4  Honus Wagner   21  2792  10430  1736  3430  640  252  101     0   963
#
#      SO   SB   CS     BA  HOF
# 0   357  892  178  0.366    1
# 1   696   78   31  0.331    1
# 2   220  432  129  0.345    1
# 3  1840  358   97  0.310    1
# 4   327  722   15  0.329    1

# %%
df.set_index("PLAYER",inplace= True)

# %%
# scale the data before performing pca
from sklearn.preprocessing import StandardScaler
s_scaler= StandardScaler()
scaled_data= s_scaler.fit_transform(df)
scaled_df= pd.DataFrame(scaled_data,columns= df.columns,index= df.index)

# %%
scaled_df.columns
# Out:
# Index(['YRS', 'G', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'SO', 'SB',
#        'CS', 'BA', 'HOF'],
#       dtype='object')

# %%
# perform pca on the scaled data
from sklearn.decomposition import PCA
pca= PCA(n_components= 3)
pca_data= pca.fit_transform(scaled_data)

# %%
pca3= pca_data[:,2]

# %%
pca2= pca_data[:,1]

# %%
# visualize the pca data using 3d plot
fig= plt.figure(figsize= (10,10))
ax= fig.add_subplot(projection= "3d")
ax.scatter(data= scaled_data,xs= pca1,ys= pca2,zs= pca3,c= df["HOF"])
